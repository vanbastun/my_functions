# %%
def get_text_without_punctuation(data):
    """
    Убрать знаки препинания из текста для дальнейшей работы со словами.
    Предварительно импортировать модуль re
    """
    data_words = re.sub('[,|.|!|?|-]', "", data)
    return data_words
